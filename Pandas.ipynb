# %%
#Answer_1

import pandas as pd
data = {'Name':['Harshit', 'kartik', 'Himanshi', 'Aisha','Sonali'],\
       'Age':[20,21,22,23,24],\
        'Mail id':['harshitahluwalia@gmail.com','kartik007@gmail.com',\
        'Himanshi@gmail.com','Aishathapa@gmail.com','Sonali23@gmail.com'],\
         'Phone Number':['7895889924','992718858',\
        '6935852693','8218958745','9625847852']
       }
df = pd.DataFrame(data)
df
# Out:
#        Name  Age                     Mail id Phone Number
# 0   Harshit   20  harshitahluwalia@gmail.com   7895889924
# 1    kartik   21         kartik007@gmail.com    992718858
# 2  Himanshi   22          Himanshi@gmail.com   6935852693
# 3     Aisha   23        Aishathapa@gmail.com   8218958745
# 4    Sonali   24          Sonali23@gmail.com   9625847852

# %%
#Answer_2

import pandas as pd
df=pd.read_csv('weather.csv')
print('THe First five rows of Data Frame are:')
print(df.head())
print('First ten rows of Data Frame are: ')
print(df.head(10))
print("The statistics on the Dataset are: ")
print(df.describe())
print("Last Five rows of Data Frame are: ")
print(df.tail())
l=df.columns
second_column=l[1]
print("Second Column is:", second_column)
df1 = pd.read_csv('weather.csv', usecols=[second_column])
print("The Statistics on the extracted second coloum are: ")
print(df1.describe())
# Out:
# THe First five rows of Data Frame are:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...
